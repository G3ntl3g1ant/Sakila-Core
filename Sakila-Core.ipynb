# %%
# Imports
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

# %%
# Create connection string using credentials following this format
# connection = "dialect+driver://username:password@host:port/database"
username = "root"
password = "root" # (or whatever password you chose during mysql installation)
db_name = "sakila"
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

# %%
engine = create_engine(connection)

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/sakila)

# %% [markdown]
# ![png](https://assets.codingdojo.com/boomyeah/company_209/chapter_3569/handouts/chapter3569_5431_sakila-db-model.png)

# %%
# Answer to question 1
q = """SELECT * FROM customer;"""
pd.read_sql(q,engine)
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id  active  \
# 0            MARY.SMITH@sakilacustomer.org           5       1
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2        LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3         BARBARA.JONES@sakilacustomer.org           8       1
# ...

# %%
# Answer for question 2 
# Because the Comedy category in the data is labeled as '5', this is what 
# was used to find the comedy films
p = """SELECT *
FROM film
JOIN film_category
ON film.film_id = film_category.film_id 
WHERE film_category.category_id = '5';"""
pd.read_sql(p,engine)
# Out:
#     film_id                    title  \
# 0         7          AIRPLANE SIERRA
# 1        28              ANTHEM LUKE
# 2        99      BRINGING HYSTERICAL
# 3       119            CAPER MOTIONS
# 4       127            CAT CONEHEADS
# 5       159              CLOSER BANG
# 6       178   CONNECTION MICROCOSMOS
# 7       182           CONTROL ANTHEM
# 8       188               CRAZY HOME
# 9       202         DADDY PITTSBURGH
# 10      242             DOOM DANCING
# 11      247          DOWNHILL ENOUGH
# 12      265              DYING MAKER
# 13      276           ELEMENT FREDDY
# 14      308            FERRIS MOTHER
# 15      317    FIREBALL PHILADELPHIA
# 16      324    FLINTSTONES HAPPINESS
# 17      332    FRANKENSTEIN STRANGER
# 18      335        FREEDOM CLEOPATRA
# 19      365               GOLD RIVER
# 20      385          GROUNDHOG UNCUT
# 21      388            GUNFIGHT MOON
# 22      404            HATE HANDICAP
# 23      410           HEAVEN FREEDOM
# ...

# %%
# Answer for question 3
# The actor's ID was labeled as '5'
t = """SELECT *
FROM film
JOIN film_actor
ON film.film_id = film_actor.film_id
WHERE film_actor.actor_id = '5';"""
pd.read_sql(t,engine)
# Out:
#     film_id                 title  \
# 0        19          AMADEUS HOLY
# 1        54      BANGER PINOCCHIO
# 2        85      BONNIE HOLOCAUST
# 3       146           CHITTY LOCK
# 4       171  COMMANDMENTS EXPRESS
# 5       172     CONEHEADS SMOOCHY
# 6       202      DADDY PITTSBURGH
# 7       203       DAISY MENAGERIE
# 8       286         ENOUGH RAGING
# 9       288     ESCAPE METROPOLIS
# 10      316           FIRE WOLVES
# 11      340        FRONTIER CABIN
# 12      369     GOODFELLAS SALUTE
# 13      375    GRAIL FRANKENSTEIN
# 14      383        GROOVE FICTION
# 15      392          HALL CASSIDY
# 16      411          HEAVENLY GUN
# 17      503      KRAMER CHOCOLATE
# 18      535         LOVE SUICIDES
# 19      571      METAL ARMAGEDDON
# 20      650       PACIFIC AMISTAD
# 21      665      PATTON INTERVIEW
# 22      687            POCUS PULP
# 23      730   RIDGEMONT SUBMARINE
# 24      732   RINGS HEARTBREAKERS
# 25      811         SMILE EARRING
# ...

# %%
# Answer for question 4
actors = """SELECT first_name, last_name
FROM actor AS a
INNER JOIN
film_actor AS fa
ON a.actor_id = fa.actor_id
INNER JOIN film AS f
ON fa.film_id = f.film_id
WHERE f.title = 'Bingo Talented';"""
pd.read_sql(actors, engine)
# Out:
#   first_name    last_name
# 0     GOLDIE        BRODY
# 1    CAMERON         WRAY
# 2       CARY  MCCONAUGHEY
# 3        JON        CHASE
# 4      RENEE         BALL

# %%
# Answer to question 5
h = """SELECT customer_id, amount
FROM payment
WHERE amount >
	2 * (SELECT AVG(amount)
	FROM payment);"""
pd.read_sql(h, engine)
# Out:
#      customer_id  amount
# 0              1    9.99
# 1              2   10.99
# 2              3    8.99
# 3              3   10.99
# 4              3    8.99
# ..           ...     ...
# 852          595    9.99
# 853          595   10.99
# 854          597    8.99
# 855          599    9.99
# 856          599    8.99
#
# [857 rows x 2 columns]

# %%
# Answer to number 6
num_payments = """SELECT customer.first_name, customer.last_name,
 (SELECT COUNT(payment_id)
 FROM payment
 WHERE customer.customer_id = payment.customer_id) AS num_payments
FROM customer
ORDER BY num_payments DESC
LIMIT 5;"""
pd.read_sql(num_payments, engine)
# Out:
#   first_name last_name  num_payments
# 0    ELEANOR      HUNT            46
# 1       KARL      SEAL            45
# 2     MARCIA      DEAN            42
# 3      CLARA      SHAW            42
# 4      TAMMY   SANDERS            41
